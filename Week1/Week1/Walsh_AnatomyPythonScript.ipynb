# %%
import re
from collections import Counter

def split_into_words(any_chunk_of_text):
    lowercase_text = any_chunk_of_text.lower()
    split_words = re.split("\W+", lowercase_text)
    return split_words

filepath_of_text = "C:/Users/murphy.465/OneDrive - The Ohio State University/Desktop/Week1/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt"
number_of_desired_words = 40

stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 've', 'll', 'amp']

full_text = open(filepath_of_text, encoding="utf-8").read()

all_the_words = split_into_words(full_text)
meaningful_words = [word for word in all_the_words if word not in stopwords]
meaningful_words_tally = Counter(meaningful_words)
most_frequent_meaningful_words = meaningful_words_tally.most_common(number_of_desired_words)

most_frequent_meaningful_words
# Out:
# [('john', 45),
#  ('one', 33),
#  ('said', 30),
#  ('would', 27),
#  ('get', 24),
#  ('see', 24),
#  ('room', 24),
#  ('pattern', 24),
#  ('paper', 23),
#  ('like', 21),
#  ('little', 20),
#  ('much', 16),
#  ('good', 16),
#  ('think', 16),
#  ('well', 15),
#  ('know', 15),
#  ('go', 15),
#  ('really', 14),
#  ('thing', 14),
#  ('wallpaper', 13),
#  ('night', 13),
#  ('long', 12),
#  ('course', 12),
#  ('things', 12),
#  ('take', 12),
#  ('always', 12),
#  ('could', 12),
#  ('jennie', 12),
#  ('great', 11),
#  ('says', 11),
#  ('feel', 11),
#  ('even', 11),
#  ('used', 11),
#  ('dear', 11),
#  ('time', 11),
#  ('enough', 11),
#  ('away', 11),
#  ('want', 11),
#  ('never', 10),
#  ('must', 10)]

# %%
meaningful_words
# Out:
# ['yellow',
#  'wallpaper',
#  'charlotte',
#  'perkins',
#  'gilman',
#  'seldom',
#  'mere',
#  'ordinary',
#  'people',
#  'like',
#  'john',
#  'secure',
#  'ancestral',
#  'halls',
#  'summer',
#  'colonial',
#  'mansion',
#  'hereditary',
#  'estate',
#  'would',
#  'say',
#  'haunted',
#  'house',
#  'reach',
#  'height',
#  'romantic',
#  'felicity',
#  'would',
#  'asking',
#  'much',
#  'fate',
#  'still',
#  'proudly',
#  'declare',
#  'something',
#  'queer',
#  'else',
#  'let',
#  'cheaply',
#  'stood',
#  'long',
#  'untenanted',
#  'john',
#  'laughs',
#  'course',
#  'one',
#  'expects',
#  'marriage',
#  'john',
#  'practical',
#  'extreme',
#  'patience',
#  'faith',
#  'intense',
#  'horror',
#  'superstition',
#  'scoffs',
#  'openly',
#  'talk',
#  'things',
#  'felt',
#  'seen',
#  'put',
#  'figures',
#  'john',
#  'physician',
#  'perhaps',
#  'would',
#  'say',
#  'living',
#  'soul',
#  'course',
#  'dead',
#  'paper',
#  'great',
#  'relief',
#  'mind',
#  'perhaps',
#  'one',
#  'reason',
#  'get',
#  'well',
#  'faster',
#  'see',
#  'believe',
#  'sick',
#  'one',
#  'physician',
#  'high',
#  'standing',
#  'one',
#  'husband',
#  'assures',
#  'friends',
#  'relatives',
#  'really',
#  'nothing',
#  'matter',
#  'one',
#  'temporary',
#  'nervous',
#  'depression',
#  'slight',
#  'hysterical',
#  'tendency',
#  'one',
#  'brother',
#  'also',
#  'physician',
#  'also',
#  'high',
#  'standing',
#  'says',
#  'thing',
#  'take',
#  'phosphates',
#  'phosphites',
#  'whichever',
#  'tonics',
#  'journeys',
#  'air',
#  'exercise',
#  'absolutely',
#  'forbidden',
#  'work',
#  'well',
#  'personally',
#  'disagree',
#  'ideas',
#  'personally',
#  'believe',
#  'congenial',
#  'work',
#  'excitement',
#  'change',
#  'would',
#  'good',
#  'one',
#  'write',
#  'spite',
#  'exhaust',
#  'good',
#  'deal',
#  'sly',
#  'else',
#  'meet',
#  'heavy',
#  'opposition',
#  'sometimes',
#  'fancy',
#  'condition',
#  'less',
#  'opposition',
#  'society',
#  'stimulus',
#  'john',
#  'says',
#  'worst',
#  'thing',
#  'think',
#  'condition',
#  'confess',
#  'always',
#  'makes',
#  'feel',
#  'bad',
#  'let',
#  'alone',
#  'talk',
#  'house',
#  'beautiful',
#  'place',
#  'quite',
#  'alone',
#  'standing',
#  'well',
#  'back',
#  'road',
#  'quite',
#  'three',
#  'miles',
#  'village',
#  'makes',
#  'think',
#  'english',
#  'places',
#  'read',
#  'hedges',
#  'walls',
#  'gates',
#  'lock',
#  'lots',
#  'separate',
#  'little',
#  'houses',
#  'gardeners',
#  'people',
#  'delicious',
#  'garden',
#  'never',
#  'saw',
#  'garden',
#  'large',
#  'shady',
#  'full',
#  'box',
#  'bordered',
#  'paths',
#  'lined',
#  'long',
#  'grape',
#  'covered',
#  'arbors',
#  'seats',
#  'greenhouses',
#  'broken',
#  'legal',
#  'trouble',
#  'believe',
#  'something',
#  'heirs',
#  'co',
#  'heirs',
#  'anyhow',
#  'place',
#  'empty',
#  'years',
#  'spoils',
#  'ghostliness',
#  'afraid',
#  'care',
#  'something',
#  'strange',
#  'house',
#  'feel',
#  'even',
#  'said',
#  'john',
#  'one',
#  'moonlight',
#  'evening',
#  'said',
#  'felt',
#  'draught',
#  'shut',
#  'window',
#  'get',
#  'unreasonably',
#  'angry',
#  'john',
#  'sometimes',
#  'm',
#  'sure',
#  'never',
#  'used',
#  'sensitive',
#  'think',
#  'due',
#  'nervous',
#  'condition',
#  'john',
#  'says',
#  'feel',
#  'shall',
#  'neglect',
#  'proper',
#  'self',
#  'control',
#  'take',
#  'pains',
#  'control',
#  'least',
#  'makes',
#  'tired',
#  'like',
#  'room',
#  'bit',
#  'wanted',
#  'one',
#  'downstairs',
#  'opened',
#  'piazza',
#  'roses',
#  'window',
#  'pretty',
#  'old',
#  'fashioned',
#  'chintz',
#  'hangings',
#  'john',
#  'would',
#  'hear',
#  'said',
#  'one',
#  'window',
#  'room',
#  'two',
#  'beds',
#  'near',
#  'room',
#  'took',
#  'another',
#  'careful',
#  'loving',
#  'hardly',
#  'lets',
#  'stir',
#  'without',
#  'special',
#  'direction',
#  'schedule',
#  'prescription',
#  'hour',
#  'day',
#  'takes',
#  'care',
#  'feel',
#  'basely',
#  'ungrateful',
#  'value',
#  'said',
#  'came',
#  'solely',
#  'account',
#  'perfect',
#  'rest',
#  'air',
#  'could',
#  'get',
#  'exercise',
#  'depends',
#  'strength',
#  'dear',
#  'said',
#  'food',
#  'somewhat',
#  'appetite',
#  'air',
#  'absorb',
#  'time',
#  'took',
#  'nursery',
#  'top',
#  'house',
#  'big',
#  'airy',
#  'room',
#  'whole',
#  'floor',
#  'nearly',
#  'windows',
#  'look',
#  'ways',
#  'air',
#  'sunshine',
#  'galore',
#  'nursery',
#  'first',
#  'playground',
#  'gymnasium',
#  'judge',
#  'windows',
#  'barred',
#  'little',
#  'children',
#  'rings',
#  'things',
#  'walls',
#  'paint',
#  'paper',
#  'look',
#  'boys',
#  'school',
#  'used',
#  'stripped',
#  'paper',
#  'great',
#  'patches',
#  'around',
#  'head',
#  'bed',
#  'far',
#  'reach',
#  'great',
#  'place',
#  'side',
#  'room',
#  'low',
#  'never',
#  'saw',
#  'worse',
#  'paper',
#  'life',
#  'one',
#  'sprawling',
#  'flamboyant',
#  'patterns',
#  'committing',
#  'every',
#  'artistic',
#  'sin',
#  'dull',
#  'enough',
#  'confuse',
#  'eye',
#  'following',
#  'pronounced',
#  'enough',
#  'constantly',
#  'irritate',
#  'provoke',
#  'study',
#  'follow',
#  'lame',
#  'uncertain',
#  'curves',
#  'little',
#  'distance',
#  'suddenly',
#  'commit',
#  'suicide',
#  'plunge',
#  'outrageous',
#  'angles',
#  'destroy',
#  'unheard',
#  'contradictions',
#  'color',
#  'repellant',
#  'almost',
#  'revolting',
#  'smouldering',
#  'unclean',
#  'yellow',
#  'strangely',
#  'faded',
#  'slow',
#  'turning',
#  'sunlight',
#  'dull',
#  'yet',
#  'lurid',
#  'orange',
#  'places',
#  'sickly',
#  'sulphur',
#  'tint',
#  'others',
#  'wonder',
#  'children',
#  'hated',
#  'hate',
#  'live',
#  'room',
#  'long',
#  'comes',
#  'john',
#  'must',
#  'put',
#  'away',
#  'hates',
#  'write',
#  'word',
#  'two',
#  'weeks',
#  'haven',
#  'felt',
#  'like',
#  'writing',
#  'since',
#  'first',
#  'day',
#  'sitting',
#  'window',
#  'atrocious',
#  'nursery',
#  'nothing',
#  'hinder',
#  'writing',
#  'much',
#  'please',
#  'save',
#  'lack',
#  'strength',
#  'john',
#  'away',
#  'day',
#  'even',
#  'nights',
#  'cases',
#  'serious',
#  'glad',
#  'case',
#  'serious',
#  'nervous',
#  'troubles',
#  'dreadfully',
#  'depressing',
#  'john',
#  'know',
#  'much',
#  'really',
#  'suffer',
#  'knows',
#  'reason',
#  'suffer',
#  'satisfies',
#  'course',
#  'nervousness',
#  'weigh',
#  'duty',
#  'way',
#  'meant',
#  'help',
#  'john',
#  'real',
#  'rest',
#  'comfort',
#  'comparative',
#  'burden',
#  'already',
#  'nobody',
#  'would',
#  'believe',
#  'effort',
#  'little',
#  'able',
#  'dress',
#  'entertain',
#  'order',
#  'things',
#  'fortunate',
#  'mary',
#  'good',
#  'baby',
#  'dear',
#  'baby',
#  'yet',
#  'cannot',
#  'makes',
#  'nervous',
#  'suppose',
#  'john',
#  'never',
#  'nervous',
#  'life',
#  'laughs',
#  'wallpaper',
#  'first',
#  'meant',
#  'repaper',
#  'room',
#  'afterwards',
#  'said',
#  'letting',
#  'get',
#  'better',
#  'nothing',
#  'worse',
#  'nervous',
#  'patient',
#  'give',
#  'way',
#  'fancies',
#  'said',
#  'wallpaper',
#  'changed',
#  'would',
#  'heavy',
#  'bedstead',
#  'barred',
#  'windows',
#  'gate',
#  'head',
#  'stairs',
#  'know',
#  'place',
#  'good',
#  'said',
#  'really',
#  'dear',
#  'care',
#  'renovate',
#  'house',
#  'three',
#  'months',
#  'rental',
#  'let',
#  'us',
#  'go',
#  'downstairs',
#  'said',
#  'pretty',
#  'rooms',
#  'took',
#  'arms',
#  'called',
#  'blessed',
#  'little',
#  'goose',
#  'said',
#  'would',
#  'go',
#  'cellar',
#  'wished',
#  'whitewashed',
#  'bargain',
#  'right',
#  'enough',
#  'beds',
#  'windows',
#  'things',
#  'airy',
#  'comfortable',
#  'room',
#  'one',
#  'need',
#  'wish',
#  'course',
#  'would',
#  'silly',
#  'make',
#  'uncomfortable',
#  'whim',
#  'm',
#  'really',
#  'getting',
#  'quite',
#  'fond',
#  'big',
#  'room',
#  'horrid',
#  'paper',
#  'one',
#  'window',
#  'see',
#  'garden',
#  'mysterious',
#  'deep',
#  'shaded',
#  'arbors',
#  'riotous',
#  'old',
#  'fashioned',
#  'flowers',
#  'bushes',
#  'gnarly',
#  'trees',
#  'another',
#  'get',
#  'lovely',
#  'view',
#  'bay',
#  'little',
#  'private',
#  'wharf',
#  'belonging',
#  'estate',
#  'beautiful',
#  'shaded',
#  'lane',
#  'runs',
#  'house',
#  'always',
#  'fancy',
#  'see',
#  'people',
#  'walking',
#  'numerous',
#  'paths',
#  'arbors',
#  'john',
#  'cautioned',
#  'give',
#  'way',
#  'fancy',
#  'least',
#  'says',
#  'imaginative',
#  'power',
#  'habit',
#  'story',
#  'making',
#  'nervous',
#  'weakness',
#  'like',
#  'mine',
#  'sure',
#  'lead',
#  'manner',
#  'excited',
#  'fancies',
#  'ought',
#  'use',
#  'good',
#  'sense',
#  'check',
#  'tendency',
#  'try',
#  'think',
#  'sometimes',
#  'well',
#  'enough',
#  'write',
#  'little',
#  'would',
#  'relieve',
#  'press',
#  'ideas',
#  'rest',
#  'find',
#  'get',
#  'pretty',
#  'tired',
#  'try',
#  'discouraging',
#  'advice',
#  'companionship',
#  'work',
#  'get',
#  'really',
#  'well',
#  'john',
#  'says',
#  'ask',
#  'cousin',
#  'henry',
#  'julia',
#  'long',
#  'visit',
#  'says',
#  'would',
#  'soon',
#  'put',
#  'fire',
#  'works',
#  'pillow',
#  'case',
#  'let',
#  'stimulating',
#  'people',
#  'wish',
#  'could',
#  'get',
#  'well',
#  'faster',
#  'must',
#  'think',
#  'paper',
#  'looks',
#  'knew',
#  'vicious',
#  'influence',
#  'recurrent',
#  'spot',
#  'pattern',
#  'lolls',
#  'like',
#  'broken',
#  'neck',
#  'two',
#  'bulbous',
#  'eyes',
#  'stare',
#  'upside',
#  'get',
#  'positively',
#  'angry',
#  'impertinence',
#  'everlastingness',
#  'sideways',
#  'crawl',
#  'absurd',
#  'unblinking',
#  'eyes',
#  'everywhere',
#  'one',
#  'place',
#  'two',
#  'breadths',
#  'didn',
#  'match',
#  'eyes',
#  'go',
#  'line',
#  'one',
#  'little',
#  'higher',
#  'never',
#  'saw',
#  'much',
#  'expression',
#  'inanimate',
#  'thing',
#  'know',
#  'much',
#  'expression',
#  'used',
#  'lie',
#  'awake',
#  'child',
#  'get',
#  'entertainment',
#  'terror',
#  'blank',
#  'walls',
#  'plain',
#  'furniture',
#  'children',
#  'could',
#  'find',
#  'toy',
#  'store',
#  'remember',
#  'kindly',
#  'wink',
#  'knobs',
#  'big',
#  'old',
#  'bureau',
#  'used',
#  'one',
#  'chair',
#  'always',
#  'seemed',
#  'like',
#  'strong',
#  'friend',
#  'used',
#  'feel',
#  'things',
#  'looked',
#  'fierce',
#  'could',
#  'always',
#  'hop',
#  'chair',
#  'safe',
#  'furniture',
#  'room',
#  'worse',
#  'inharmonious',
#  'however',
#  'bring',
#  'downstairs',
#  'suppose',
#  'used',
#  'playroom',
#  'take',
#  'nursery',
#  'things',
#  'wonder',
#  'never',
#  'saw',
#  'ravages',
#  'children',
#  'made',
#  'wallpaper',
#  'said',
#  'torn',
#  'spots',
#  'sticketh',
#  'closer',
#  'brother',
#  'must',
#  'perseverance',
#  'well',
#  'hatred',
#  'floor',
#  'scratched',
#  'gouged',
#  'splintered',
#  'plaster',
#  'dug',
#  'great',
#  'heavy',
#  'bed',
#  'found',
#  'room',
#  'looks',
#  'wars',
#  'mind',
#  'bit',
#  'paper',
#  'comes',
#  'john',
#  'sister',
#  'dear',
#  'girl',
#  'careful',
#  'must',
#  'let',
#  'find',
#  'writing',
#  'perfect',
#  'enthusiastic',
#  'housekeeper',
#  'hopes',
#  'better',
#  'profession',
#  'verily',
#  'believe',
#  'thinks',
#  'writing',
#  'made',
#  'sick',
#  'write',
#  'see',
#  'long',
#  'way',
#  'windows',
#  'one',
#  'commands',
#  'road',
#  'lovely',
#  'shaded',
#  'winding',
#  'road',
#  'one',
#  'looks',
#  'country',
#  'lovely',
#  'country',
#  'full',
#  'great',
#  'elms',
#  'velvet',
#  'meadows',
#  'wallpaper',
#  'kind',
#  'sub',
#  'pattern',
#  'different',
#  'shade',
#  'particularly',
#  'irritating',
#  'one',
#  'see',
#  'certain',
#  'lights',
#  'clearly',
#  'places',
#  'isn',
#  'faded',
#  'sun',
#  'see',
#  'strange',
#  'provoking',
#  'formless',
#  'sort',
#  'figure',
#  'seems',
#  'sulk',
#  'behind',
#  'silly',
#  'conspicuous',
#  'front',
#  'design',
#  'sister',
#  'stairs',
#  'well',
#  'fourth',
#  'july',
#  'people',
#  'gone',
#  'tired',
#  'john',
#  'thought',
#  'might',
#  'good',
#  'see',
#  'little',
#  'company',
#  'mother',
#  'nellie',
#  'children',
#  'week',
#  'course',
#  'didn',
#  'thing',
#  'jennie',
#  'sees',
#  'everything',
#  'tired',
#  'john',
#  'says',
#  'pick',
#  'faster',
#  'shall',
#  'send',
#  'weir',
#  'mitchell',
#  'fall',
#  'want',
#  'go',
#  'friend',
#  'hands',
#  'says',
#  'like',
#  'john',
#  ...]
